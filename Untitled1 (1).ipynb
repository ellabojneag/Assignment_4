# %%
# import libraries/modules

import os
import pandas as pd 
import numpy as np

# %%
# find location where csv files are saved

pwd
# Out:
# 'C:\\Users\\ellab\\Desktop\\Class Repo\\RUTSOM201801DATA5-Class-Repository-DATA\\04-Pandas\\2-homework\\Instructions\\PyCitySchools\\raw_data'

# %%
# Point files to path directory 

file_1="schools_complete.csv"
file_2="students_complete.csv"

# %%
# Open files using pandas read_csv

schools_df=pd.read_csv(file_1)
students_df=pd.read_csv(file_2)

# %%
# Display  School DataFrames Created using head()

schools_df.head()
# Out:
#    School ID                   name      type  size   budget
# 0          0      Huang High School  District  2917  1910635
# 1          1   Figueroa High School  District  2949  1884411
# 2          2    Shelton High School   Charter  1761  1056600
# 3          3  Hernandez High School  District  4635  3022020
# 4          4    Griffin High School   Charter  1468   917500

# %%
# Display Student DataFrames Created using head()

students_df.head()
# Out:
#    Student ID               name gender grade             school  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score
# 0             66          79
# 1             94          61
# 2             90          60
# 3             67          58
# 4             97          84

# %%
# Finding number of different schools
Total_schools=len(schools_df["name"].unique())
Total_schools
# Out:
# 15

# %%
# Finding number of students
Total_Students=len(students_df["name"])
Total_Students
# Out:
# 39170

# %%
# Finding schools' total budget
Total_Budget=schools_df["budget"].sum()
Total_Budget
# Out:
# 24649428

# %%
# Finding students' average math score
M_Mean=students_df["math_score"].mean()
M_Mean
# Out:
# 78.98537145774827

# %%
# Finding student's average reading score
R_Mean=students_df["reading_score"].mean()
R_Mean
# Out:
# 81.87784018381414

# %%
# Making sure none of the rows are empty/missing information
students_df.count()
# Out:
# Student ID       39170
# name             39170
# gender           39170
# grade            39170
# school           39170
# reading_score    39170
# math_score       39170
# dtype: int64

# %%
# Percent of students passing Math 
Passing_Math_Grade=students_df.loc[students_df["math_score"]>=60,:]
Passing_M_Students=len(Passing_Math_Grade["math_score"])
a=(Passing_M_Students/Total_Students)*100
a
# Out:
# 92.4457492979321

# %%
# Percent of students passing Reading 
Passing_Reading_Grades=students_df.loc[students_df["reading_score"]>=60,:]
Passing_R_Students=len(Passing_Reading_Grades["reading_score"])
b=(Passing_R_Students/Total_Students)*100
b
# Out:
# 100.0

# %%
# Overall Passing Rate
c=(a+b)/2
c
# Out:
# 96.22287464896604

# %%
# Create Data Frame from List of Dictionary 
=[{"Total Schools":Total_schools,"Total Students":Total_Students, "Total Budget":Total_Budget, "Average Math Score":M_Mean, "Average Reading Score":R_Mean, "% Passing Math":a, "% Passing Reading":b, "Overall Passing Rate":c}]
pd.DataFrame(District_Summary)
# Out:
#    % Passing Math  % Passing Reading  Average Math Score  \
# 0       92.445749              100.0           78.985371
#
#    Average Reading Score  Overall Passing Rate  Total Budget  Total Schools  \
# 0               81.87784             96.222875      24649428             15
#
#    Total Students
# 0           39170

# %%
# Re-named the columns of schools_df
schools_df_2=schools_df.rename(columns={'name':'School Name','type':'School Type', 'size':'Total Students','budget':'Total School Budget'})

# Deleted School I.D
del schools_df_2['School ID']

(schools_df_2)
# Out:
#               School Name School Type  Total Students  Total School Budget
# 0       Huang High School    District            2917              1910635
# 1    Figueroa High School    District            2949              1884411
# 2     Shelton High School     Charter            1761              1056600
# 3   Hernandez High School    District            4635              3022020
# 4     Griffin High School     Charter            1468               917500
# 5      Wilson High School     Charter            2283              1319574
# 6     Cabrera High School     Charter            1858              1081356
# 7      Bailey High School    District            4976              3124928
# 8      Holden High School     Charter             427               248087
# 9        Pena High School     Charter             962               585858
# 10     Wright High School     Charter            1800              1049400
# ...

# %%
# Calculated new column for Student Budget
Student_Budget=schools_df_2["Total School Budget"]/schools_df_2["Total Students"]

# Put Per Student Budget in Data Frame
Per_Student_Budget=pd.DataFrame(Student_Budget)
Per_Student_Budget

# Appended New Per Student Budget to Schools_df_2 dataframe
schools_df_2["Per Student Budget"]=Per_Student_Budget
schools_df_2
# Out:
#               School Name School Type  Total Students  Total School Budget  \
# 0       Huang High School    District            2917              1910635
# 1    Figueroa High School    District            2949              1884411
# 2     Shelton High School     Charter            1761              1056600
# 3   Hernandez High School    District            4635              3022020
# 4     Griffin High School     Charter            1468               917500
# 5      Wilson High School     Charter            2283              1319574
# 6     Cabrera High School     Charter            1858              1081356
# 7      Bailey High School    District            4976              3124928
# 8      Holden High School     Charter             427               248087
# 9        Pena High School     Charter             962               585858
# 10     Wright High School     Charter            1800              1049400
# ...

# %%
students_df.head(200)
# Out:
#      Student ID                  name gender grade             school  \
# 0             0          Paul Bradley      M   9th  Huang High School
# 1             1          Victor Smith      M  12th  Huang High School
# 2             2       Kevin Rodriguez      M  12th  Huang High School
# 3             3     Dr. Richard Scott      M  12th  Huang High School
# 4             4            Bonnie Ray      F   9th  Huang High School
# 5             5         Bryan Miranda      M   9th  Huang High School
# 6             6         Sheena Carter      F  11th  Huang High School
# 7             7          Nicole Baker      F  12th  Huang High School
# 8             8          Michael Roth      M  10th  Huang High School
# 9             9        Matthew Greene      M  10th  Huang High School
# 10           10      Andrew Alexander      M  10th  Huang High School
# 11           11         Daniel Cooper      M  10th  Huang High School
# ...
